# %% [markdown]
# # Jack's Car Rental

# %% [markdown]
# Jack's Car Rental is an example first introduced in Chapter 4, Example 4.2 to illustrate *policy iteration*.

# %% [markdown]
# Unfortunately, it's not very well described, with the most confusing part being the limit of 20 on the number of cars at each location, which doesn't seem to apply to the cars that are moved from one location to the other overnight. This means that you can start with at most 25 cars at one location at the start of the business day (in case you closed at one location with 20 cars the day before and had 5 cars moved there overnight).

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import itertools
import scipy.stats

# %% [markdown]
# ## Initialization

# %%
# The number of cars we can keep at a single location
numcars = 20

# Maximum number of cars we can transfer from one location
# to the other overnight
maxtransfer = 5

# Discount rate
gamma = 0.9

# State value functions
V = np.zeros((numcars+1, numcars+1))
# Policy
pi = np.zeros((numcars+1, numcars+1), dtype=int)

# %%
def probabilities_rewards(l_req, l_ret, numcars, maxtransfer):
    # l_req: expected number of requests
    # l_ret: expected number of returns
    
    # ps[x,y]: probability of starting the day with x cars
    #          and finishing with y
    ps = np.zeros((numcars+maxtransfer+1, numcars+1))
    
    # r[x]: the expected reward from rentals when starting the day
    # with x cars
    rs = np.zeros((numcars+maxtransfer+1,))
    
    # i: the number of cars at the start of the day (this can probably 
    # be up to numcars + maxtransfer)
    for i in range(numcars+maxtransfer+1):
        # I can satisfy at most i requests
        for requests in range(i+1):
            if requests < i:
                # The probability of having i requests
                prob_requests = scipy.stats.poisson.pmf(requests, l_req)
            else:
                # For requests >= i the end result is the same (I rent out
                # i cars), therefore I sum the probabilities of having
                # i or more requests.
                prob_requests = (scipy.stats.poisson.pmf(requests, l_req) + 
                                 1 - scipy.stats.poisson.cdf(requests, l_req))
        
            # Let's update the expected reward
            rs[i] += requests * 10 * prob_requests
            
            # How many cars I can take in (until the rental place gets full)
            # This is negative in case I have more cars than I can keep.
            max_returns = numcars - i + requests
            if max_returns > 0:
                # If there is still some space for cars
                
                for returns in range(max_returns+1):
                    if returns < max_returns:
                        # The probability of having this many returns
                        prob_returns = scipy.stats.poisson.pmf(returns, l_ret)
                    else:
                        # The probability of returns >= max_returns
                        prob_returns = (scipy.stats.poisson.pmf(returns, l_ret) + 
                                        1-scipy.stats.poisson.cdf(returns, l_ret))
                    
                    # The number of cars at the end of the day (before transfers)
                    doorclosed = i - requests + returns
                    # Let's update the probability of starting the day with i cars 
                    # and finishing it with doorclosed cars.
                    ps[i, doorclosed] += prob_requests * prob_returns
            else:
                # In case I already have exactly numcars or more at the location, 
                # I will end up having the location full at the end of the day anyway,
                # irrespective of how many returned cars there will be.
                ps[i, numcars] += prob_requests * 1
                
    return ps, rs

# %%
# Probabilities and rewards for the first location
ps1, rs1 = probabilities_rewards(3,3, numcars, maxtransfer)
# Second location
ps2, rs2 = probabilities_rewards(4,2, numcars, maxtransfer)

# %% [markdown]
# ## Policy Evaluation

# %%
def policy_evaluation(V, pi, numcars, ps1, rs1, ps2, rs2, theta):
    numiter = 0
    while True:
        numiter += 1

        delta = 0

        # Let's iterate over all states (evening, day T, before transfer)
        # i: number of cars at the first location
        # j: number of cars at the second location
        for i, j in itertools.product(range(numcars+1), range(numcars+1)):

            # Value at iteration numiter - 1
            v = V[i,j]

            # Action according to current policy (number of cars moved from
            # first location to the second location)
            action = pi[i,j]

            # Number of cars at both locations the next day (day T+1) in the
            # morning after performing action.
            nextday = (i-action, j+action)

            # Initiate the new value with:
            # (the expected reward for the transfers)
            # + (the expected reward for the rentals given the number of cars 
            #    at the start of the day T+1)
            new_value = np.abs(action)*(-2) + (rs1[nextday[0]] + rs2[nextday[1]])

            # Let's iterate over all states s' (evening, day T+1, before transfer)
            for ii, jj in itertools.product(range(numcars+1), range(numcars+1)):
                new_value += (ps1[nextday[0],ii]*ps2[nextday[1],jj] 
                              # probability of s' given s
                              * gamma * V[ii,jj])

            V[i,j] = new_value
            delta = max(delta, np.abs(v - V[i,j]))

        print('Policy evaluation, iteration {}, delta: {}'.format(numiter, delta))
        if delta < theta:
            break
            
    return V

# %% [markdown]
# ## Policy improvement

# %%
def policy_improvement(V, pi, numcars, maxtransfer, ps1, rs1, ps2, rs2, theta):
    policy_stable = True

    # Let's iterate over all states (this is in the evening, day T, before transfer)
    for i, j in itertools.product(range(numcars+1), range(numcars+1)):    
        # Action from the last iteration
        a = pi[i,j]

        # The maximum number of cars I can move from location one to two
        maxaction = min(maxtransfer, i)
        # The maximum number of cars I can move from location two to one
        minaction = -min(maxtransfer, j)

        # All possible actions
        actions = list(range(minaction, maxaction+1))

        # Let's calculate q(s,a) for all actions
        q = [0] * len(actions)
        for action_idx, action in enumerate(actions):
            # The number of cars at both locations after preforming the action
            # (this is morning, day T+1)
            nextday = (i-action, j+action)

            # Initiate the action value with the expected reward for rentals
            # given the number of cars at both locations in the morning of
            # day T+1
            q[action_idx] = rs1[nextday[0]] + rs2[nextday[1]] + np.abs(action)*(-2)

            # Let's iterate over all s' (evening, day T+1)
            for ii, jj in itertools.product(range(numcars+1), range(numcars+1)):
                q[action_idx] += (
                    ps1[nextday[0],ii]*ps2[nextday[1],jj]
                    * (gamma * V[ii,jj])
                )

        # Pick the action with the highest q(s,a)
        pi[i,j] = actions[np.argmax(q)]

        if pi[i,j] != a:
            policy_stable = False
    
    return pi, policy_stable

# %% [markdown]
# ## Policy iteration

# %%
theta = 0.000001

num_policy_iterations = 4
pis = []
Vs = []

for i in range(num_policy_iterations):
    print("POLICY ITERATION {}".format(i+1))

    V = policy_evaluation(V, pi, numcars, ps1, rs1, ps2, rs2, theta)
    pi, policy_stable = policy_improvement(V, pi, numcars, 
                                           maxtransfer, ps1, rs1, ps2, rs2, 
                                           theta)
    
    print('Was policy stable?: {}'.format(policy_stable))
    pis.append(np.copy(pi))
    Vs.append(np.copy(V))
# Out:
# POLICY ITERATION 1
# Policy evaluation, iteration 1, delta: 193.34904927512346
# Policy evaluation, iteration 2, delta: 134.00426086449986
# Policy evaluation, iteration 3, delta: 90.45243773749047
# Policy evaluation, iteration 57, delta: 0.0020151360427576037
# Policy evaluation, iteration 58, delta: 0.0016535389446517001
# Policy evaluation, iteration 59, delta: 0.001356819519344299
# Policy evaluation, iteration 60, delta: 0.0011133395327647122
# Policy evaluation, iteration 61, delta: 0.0009135479153314918
# Policy evaluation, iteration 62, delta: 0.0007496066169778715
# Policy evaluation, iteration 63, delta: 0.0006150834902314273
# Policy evaluation, iteration 64, delta: 0.0005047002084097585
# Policy evaluation, iteration 65, delta: 0.00041412533960283326
# Policy evaluation, iteration 66, delta: 0.00033980453349613526
# Policy evaluation, iteration 67, delta: 0.000278821134259033
# Policy evaluation, iteration 68, delta: 0.0002287818015247467
# Policy evaluation, iteration 69, delta: 0.00018772262319544097
# Policy evaluation, iteration 70, delta: 0.00015403208328734763
# Policy evaluation, iteration 71, delta: 0.00012638783164220513
# Policy evaluation, iteration 72, delta: 0.0001037048113516903
# Policy evaluation, iteration 73, delta: 8.509267132694731e-05
# Policy evaluation, iteration 74, delta: 6.982084272522115e-05
# Policy evaluation, iteration 75, delta: 5.728985252062557e-05
# Policy evaluation, iteration 76, delta: 4.700781687461131e-05
# Policy evaluation, iteration 77, delta: 3.8571118068375654e-05
# Policy evaluation, iteration 78, delta: 3.1648575713916216e-05
# Policy evaluation, iteration 79, delta: 2.5968444731461204e-05
# Policy evaluation, iteration 80, delta: 2.1307748568233364e-05
# Policy evaluation, iteration 81, delta: 1.748352741515191e-05
# Policy evaluation, iteration 82, delta: 1.4345656325076561e-05
# Policy evaluation, iteration 83, delta: 1.1770954131407052e-05
# Policy evaluation, iteration 84, delta: 9.658348801622196e-06
# Policy evaluation, iteration 85, delta: 7.9249025475292e-06
# Policy evaluation, iteration 86, delta: 6.5025695903386804e-06
# Policy evaluation, iteration 87, delta: 5.335509740689304e-06
# Policy evaluation, iteration 88, delta: 4.377910443054134e-06
# Policy evaluation, iteration 89, delta: 3.5921766539104283e-06
# Policy evaluation, iteration 90, delta: 2.947464679436962e-06
# Policy evaluation, iteration 91, delta: 2.4184622589018545e-06
# Policy evaluation, iteration 92, delta: 1.9844039229610644e-06
# Policy evaluation, iteration 93, delta: 1.628249322038755e-06
# Policy evaluation, iteration 94, delta: 1.336015714059613e-06
# Policy evaluation, iteration 95, delta: 1.0962311876028252e-06
# Policy evaluation, iteration 96, delta: 8.994829840958118e-07
# Was policy stable?: False
# POLICY ITERATION 2
# Policy evaluation, iteration 1, delta: 64.53798445717126
# Policy evaluation, iteration 2, delta: 3.7843637718008267
# Policy evaluation, iteration 3, delta: 1.8697478690243088
# Policy evaluation, iteration 4, delta: 1.5356820827449837
# Policy evaluation, iteration 5, delta: 1.3327414854471158
# Policy evaluation, iteration 6, delta: 1.1067642066001326
# Policy evaluation, iteration 7, delta: 0.9086304559634755
# Policy evaluation, iteration 8, delta: 0.7442707580460137
# Policy evaluation, iteration 9, delta: 0.6093306580444278
# Policy evaluation, iteration 62, delta: 1.4901367990205472e-05
# Policy evaluation, iteration 63, delta: 1.2195838166917383e-05
# Policy evaluation, iteration 64, delta: 9.981532002711901e-06
# Policy evaluation, iteration 65, delta: 8.169260240720178e-06
# Policy evaluation, iteration 66, delta: 6.686028314106807e-06
# Policy evaluation, iteration 67, delta: 5.472097541314724e-06
# Policy evaluation, iteration 68, delta: 4.478569792354392e-06
# Policy evaluation, iteration 69, delta: 3.6654294603977178e-06
# Policy evaluation, iteration 70, delta: 2.9999246748957376e-06
# Policy evaluation, iteration 71, delta: 2.4552513764319883e-06
# Policy evaluation, iteration 72, delta: 2.009469653785345e-06
# Policy evaluation, iteration 73, delta: 1.6446252857349464e-06
# Policy evaluation, iteration 74, delta: 1.346023054793477e-06
# Policy evaluation, iteration 75, delta: 1.1016357461812731e-06
# Policy evaluation, iteration 76, delta: 9.016200124278839e-07
# Was policy stable?: False
# POLICY ITERATION 3
# Policy evaluation, iteration 1, delta: 5.113984544551386
# Policy evaluation, iteration 2, delta: 3.125005929540066
# Policy evaluation, iteration 3, delta: 2.131359576108025
# Policy evaluation, iteration 4, delta: 1.4763815375780496
# Policy evaluation, iteration 5, delta: 0.9889113991832801
# Policy evaluation, iteration 6, delta: 0.6514663459967096
# Policy evaluation, iteration 7, delta: 0.43003480518029846
# Policy evaluation, iteration 8, delta: 0.2892550604997268
# Policy evaluation, iteration 9, delta: 0.2090513984513791
# Policy evaluation, iteration 10, delta: 0.15912610160273744
# Policy evaluation, iteration 11, delta: 0.12445002531831051
# Policy evaluation, iteration 12, delta: 0.1022863418283464
# Policy evaluation, iteration 13, delta: 0.08396295794119624
# Policy evaluation, iteration 14, delta: 0.06886645248118839
# Policy evaluation, iteration 15, delta: 0.05645520940862525
# Policy evaluation, iteration 16, delta: 0.046265429925085755
# Policy evaluation, iteration 17, delta: 0.03790673971138858
# Policy evaluation, iteration 18, delta: 0.031053905785142888
# Policy evaluation, iteration 19, delta: 0.025437655626433298
# Policy evaluation, iteration 20, delta: 0.020835917451051955
# Policy evaluation, iteration 21, delta: 0.017065998607677102
# Policy evaluation, iteration 22, delta: 0.013977839809058423
# Policy evaluation, iteration 23, delta: 0.01144831109019151
# Policy evaluation, iteration 24, delta: 0.009376445359691843
# Policy evaluation, iteration 25, delta: 0.007679484325024077
# Policy evaluation, iteration 26, delta: 0.0062896133561025636
# Policy evaluation, iteration 27, delta: 0.0051512730673834994
# Policy evaluation, iteration 28, delta: 0.004218949905236968
# Policy evaluation, iteration 29, delta: 0.0034553625754938366
# Policy evaluation, iteration 30, delta: 0.0028299745432036616
# Policy evaluation, iteration 31, delta: 0.0023177746165288227
# Policy evaluation, iteration 32, delta: 0.0018982776080633812
# Policy evaluation, iteration 33, delta: 0.0015547055529054887
# Policy evaluation, iteration 34, delta: 0.0012733169200487282
# Policy evaluation, iteration 35, delta: 0.0010428571636111883
# Policy evaluation, iteration 36, delta: 0.0008541086492641625
# Policy evaluation, iteration 37, delta: 0.0006995220246039935
# Policy evaluation, iteration 38, delta: 0.0005729142897621387
# Policy evaluation, iteration 39, delta: 0.000469221504943107
# Policy evaluation, iteration 40, delta: 0.0003842962595967947
# Policy evaluation, iteration 41, delta: 0.0003147417849049816
# Policy evaluation, iteration 42, delta: 0.0002577760985786881
# Policy evaluation, iteration 43, delta: 0.00021112073477524973
# Policy evaluation, iteration 44, delta: 0.00017290960960281154
# Policy evaluation, iteration 45, delta: 0.00014161438485871258
# Policy evaluation, iteration 46, delta: 0.00011598333998108501
# Policy evaluation, iteration 47, delta: 9.499130430867808e-05
# Policy evaluation, iteration 48, delta: 7.779865507018258e-05
# Policy evaluation, iteration 49, delta: 6.371773537239278e-05
# Policy evaluation, iteration 50, delta: 5.218534607820402e-05
# Policy evaluation, iteration 51, delta: 4.274022501249419e-05
# Policy evaluation, iteration 52, delta: 3.5004595019927365e-05
# Policy evaluation, iteration 53, delta: 2.866904929987868e-05
# Policy evaluation, iteration 54, delta: 2.348018563225196e-05
# Policy evaluation, iteration 55, delta: 1.9230464090469468e-05
# Policy evaluation, iteration 56, delta: 1.574990727704062e-05
# Policy evaluation, iteration 57, delta: 1.289930349912538e-05
# Policy evaluation, iteration 58, delta: 1.0564634578713594e-05
# Policy evaluation, iteration 59, delta: 8.652522240026883e-06
# Policy evaluation, iteration 60, delta: 7.086486505158973e-06
# Policy evaluation, iteration 61, delta: 5.803890303468506e-06
# Policy evaluation, iteration 62, delta: 4.753433358928305e-06
# Policy evaluation, iteration 63, delta: 3.893101109042618e-06
# Policy evaluation, iteration 64, delta: 3.188481969118584e-06
# Policy evaluation, iteration 65, delta: 2.611392403650825e-06
# Policy evaluation, iteration 66, delta: 2.13875267718322e-06
# Policy evaluation, iteration 67, delta: 1.7516550201435166e-06
# Policy evaluation, iteration 68, delta: 1.434619775864121e-06
# Policy evaluation, iteration 69, delta: 1.1749658597182133e-06
# Policy evaluation, iteration 70, delta: 9.623062169339391e-07
# Was policy stable?: False
# POLICY ITERATION 4
# Policy evaluation, iteration 1, delta: 0.509434332779847
# Policy evaluation, iteration 2, delta: 0.16380573129242748
# Policy evaluation, iteration 3, delta: 0.0829499098914539
# Policy evaluation, iteration 4, delta: 0.05222278496239596
# Policy evaluation, iteration 5, delta: 0.035789652053608734
# Policy evaluation, iteration 6, delta: 0.023524803901182167
# Policy evaluation, iteration 7, delta: 0.015075745266926788
# Policy evaluation, iteration 8, delta: 0.009664655768347075
# Policy evaluation, iteration 9, delta: 0.006306240314756906
# Policy evaluation, iteration 10, delta: 0.00424211424672194
# Policy evaluation, iteration 11, delta: 0.003118292316003135
# Policy evaluation, iteration 12, delta: 0.0024529982158583152
# Policy evaluation, iteration 13, delta: 0.0020156700749112133
# Policy evaluation, iteration 14, delta: 0.0016544333971069136
# Policy evaluation, iteration 15, delta: 0.0013569074441761586
# Policy evaluation, iteration 16, delta: 0.0011123275027671298
# Policy evaluation, iteration 17, delta: 0.0009115287629128943
# Policy evaluation, iteration 18, delta: 0.0007468136903412415
# Policy evaluation, iteration 19, delta: 0.0006117736347164282
# Policy evaluation, iteration 20, delta: 0.0005011032912420887
# Policy evaluation, iteration 21, delta: 0.0004104270134348553
# Policy evaluation, iteration 22, delta: 0.000336144631546631
# Policy evaluation, iteration 23, delta: 0.0002752987151097841
# Policy evaluation, iteration 24, delta: 0.00022546237141796155
# Policy evaluation, iteration 25, delta: 0.00018464543018126278
# Policy evaluation, iteration 26, delta: 0.0001512166018642347
# Policy evaluation, iteration 27, delta: 0.00012383916129010686
# Policy evaluation, iteration 28, delta: 0.00010141797872620373
# Policy evaluation, iteration 29, delta: 8.30559675364384e-05
# Policy evaluation, iteration 30, delta: 6.801834177849742e-05
# Policy evaluation, iteration 31, delta: 5.570327977011402e-05
# Policy evaluation, iteration 32, delta: 4.56178890431147e-05
# Policy evaluation, iteration 33, delta: 3.7358496911110706e-05
# Policy evaluation, iteration 34, delta: 3.059450801856656e-05
# Policy evaluation, iteration 35, delta: 2.5055175910893013e-05
# Policy evaluation, iteration 36, delta: 2.0518772203104163e-05
# Policy evaluation, iteration 37, delta: 1.6803713265289844e-05
# Policy evaluation, iteration 38, delta: 1.376128977881308e-05
# Policy evaluation, iteration 39, delta: 1.1269715571415873e-05
# Policy evaluation, iteration 40, delta: 9.229258012055652e-06
# Policy evaluation, iteration 41, delta: 7.558238621641067e-06
# Policy evaluation, iteration 42, delta: 6.189768555486808e-06
# Policy evaluation, iteration 43, delta: 5.06906900454851e-06
# Policy evaluation, iteration 44, delta: 4.1512801089993445e-06
# Policy evaluation, iteration 45, delta: 3.3996631714217074e-06
# Policy evaluation, iteration 46, delta: 2.7841307428388973e-06
# Policy evaluation, iteration 47, delta: 2.280045180214074e-06
# Policy evaluation, iteration 48, delta: 1.86722763828584e-06
# Policy evaluation, iteration 49, delta: 1.5291529393834935e-06
# Policy evaluation, iteration 50, delta: 1.2522904739853402e-06
# Policy evaluation, iteration 51, delta: 1.0255544680148887e-06
# Policy evaluation, iteration 52, delta: 8.398713475799013e-07
# Was policy stable?: False

# %%
# Plot results

# Policies
f, axarr = plt.subplots(1, num_policy_iterations, figsize=(15, 4))
f.suptitle(r'$\pi$', fontsize=30) ;

for i in range(num_policy_iterations):
    axarr[i].imshow(pis[i], interpolation="nearest", origin='lower') ;
    
    axarr[i].set_title("Policy iteration {}".format(i+1))
    if i == 0:
        axarr[i].set_ylabel('#cars at first location') ;
        axarr[i].set_xlabel('#cars at second location') ;

# Value function at the last iteration
f2 = plt.figure()
plt.imshow(Vs[-1], interpolation="nearest", origin='lower') ;
plt.colorbar() ;
plt.title('Value function at iteration {}'.format(num_policy_iterations)) ;
plt.ylabel('#cars at first location') ;
plt.xlabel('#cars at second location') ;
